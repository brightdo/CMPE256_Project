# %%
import pandas as pd
data = pd.read_csv('Automotive_5.csv')
data.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        4     False   05 1, 2015   A8WEXFRWX1ZHH  0209688726
# 1        1      True  04 19, 2018   ABCA1A8E4DGV1  0209688726
# 2        1      True  04 16, 2018  A1NX8HM89FRQ32  0209688726
# 3        3      True  04 13, 2018  A1X77G023NY0KY  0209688726
# 4        5      True   04 8, 2018  A3GK37JO2MGW6Q  0209688726
#
#                   style reviewerName  \
# 0     {'Color:': ' AC'}   Goldengate
# 1   {'Color:': ' Blue'}          noe
# 2  {'Color:': ' Black'}       Eduard
# 3     {'Color:': ' CA'}       Lauren
# 4  {'Color:': ' Black'}        danny
#
#                                           reviewText  \
# 0  After I wrote the below review, the manufactur...
# ...

# %%
data.describe()
# Out:
#             overall  unixReviewTime
# count  1.711519e+06    1.711519e+06
# mean   4.459656e+00    1.454263e+09
# std    1.055129e+00    4.913828e+07
# min    1.000000e+00    9.688896e+08
# 25%    4.000000e+00    1.424909e+09
# 50%    5.000000e+00    1.460678e+09
# 75%    5.000000e+00    1.490659e+09
# max    5.000000e+00    1.538525e+09

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1711519 entries, 0 to 1711518
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   overall         int64
#  1   verified        bool
#  2   reviewTime      object
#  3   reviewerID      object
#  4   asin            object
#  5   style           object
#  6   reviewerName    object
#  7   reviewText      object
#  8   summary         object
#  9   unixReviewTime  int64
#  10  vote            object
#  11  image           object
# dtypes: bool(1), int64(2), object(9)
# memory usage: 145.3+ MB

# %%
data.sort_values(by=['unixReviewTime'])
# Out:
#          overall  verified   reviewTime      reviewerID        asin  \
# 766            5      True  09 14, 2000  A3TB9HNQR54B5V  B0000225EL
# 98             1     False  05 23, 2001   AY7CGSWDQ3SRL  1563923815
# 1319853        5      True  04 23, 2002  A35UIYSKD6PVEG  B00NBC4IAC
# 1153           1     False  07 22, 2002  A39XIRZI48YGZL  B00004Y774
# 1329263        5     False  09 24, 2002   AERYJMGYQEJZP  B00V82FB58
# ...          ...       ...          ...             ...         ...
# 1711341        2     False   10 2, 2018  A2R82FNIK83TD4  B01HEHOAS4
# 1711172        5      True   10 2, 2018  A33YDWTNM70GRG  B01H9XALY0
# 1711397        5      True   10 2, 2018  A3LA146D5ZTSWM  B01HFMNYIU
# 1711242        4      True   10 2, 2018  A2OY03FVH4OYKX  B01HC3QIGM
# 1711249        5      True   10 3, 2018  A2DIG40N5NIQQW  B01HC6GZSK
#
#                                                  style    reviewerName  \
# 766                                                NaN            John
# ...

# %%
col = data['unixReviewTime'].copy()
hist = col.hist(bins=50)

# %%
df = data[data['unixReviewTime'] >= 1451635200]

# Print the shape of the dataframe
print(df.shape)
# Out:
# (971070, 12)

# %%
df.isna().sum()
# Out:
# overall                0
# verified               0
# reviewTime             0
# reviewerID             0
# asin                   0
# style             615451
# reviewerName         114
# reviewText           687
# summary              264
# unixReviewTime         0
# vote              897070
# image             938887
# dtype: int64

# %%
cols_drop = ['reviewerName', 'reviewText', 'summary', 'image', 'vote']
df = df.drop(cols_drop, axis=1)
df.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 1        1      True  04 19, 2018   ABCA1A8E4DGV1  0209688726
# 2        1      True  04 16, 2018  A1NX8HM89FRQ32  0209688726
# 3        3      True  04 13, 2018  A1X77G023NY0KY  0209688726
# 4        5      True   04 8, 2018  A3GK37JO2MGW6Q  0209688726
# 5        5      True  03 24, 2018   AIY18YON1TWJJ  0209688726
#
#                   style  unixReviewTime
# 1   {'Color:': ' Blue'}      1524096000
# 2  {'Color:': ' Black'}      1523836800
# 3     {'Color:': ' CA'}      1523577600
# 4  {'Color:': ' Black'}      1523145600
# 5  {'Color:': ' Black'}      1521849600

# %%
df.groupby('verified').count()
# print(len(df['verified'] == False))
# Out:
#           overall  reviewTime  reviewerID    asin   style  unixReviewTime
# verified
# False       34874       34874       34874   34874   15635           34874
# True       936196      936196      936196  936196  339984          936196

# %%
df['verified'].value_counts()
# Out:
# True     936196
# False     34874
# Name: verified, dtype: int64

# %%
df1 = df.copy()
df2 = df1[df1['verified'] == True]
# df1 = df1.drop(df['verified'], axis=1)
# df1.groupby('verified').count() 
df2['verified'].unique()
# Out:
# array([ True])

# %%
print(df2.shape)
# Out:
# (936196, 7)

# %%
df2.isna().sum()
# Out:
# overall                0
# verified               0
# reviewTime             0
# reviewerID             0
# asin                   0
# style             596212
# unixReviewTime         0
# dtype: int64

# %%
style = df2['style'].unique()

# %%
import numpy as np

np.savetxt('style.txt', style, delimiter=',', fmt='%s')   # X is an array

# file = open('style.txt',"w+")
# file.write(df2['style'].unique())

# %%
df2.to_csv('automotive.csv')
